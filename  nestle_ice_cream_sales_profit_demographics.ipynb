# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
np.random.seed(42)

# %%
n_records = 5000  # total number of transactions or aggregated records

regions = ['North', 'South', 'East', 'West']
age_groups = ['Under 18', '18-34', '35-54', '55+']
income_levels = ['Low', 'Lower-middle', 'Middle', 'Upper-middle', 'High']
family_sizes = ['1', '2', '3-4', '5+']

# price and cost assumptions
avg_price_per_unit = 3.5   # USD
price_std = 0.75
cost_margin = 0.6  # cost is 60% of price on average

# %%
import pandas as pd

# Example synthetic dataset
data = {
    "Month": ["Jan", "Feb", "Mar"],
    "Sales": [12000, 15000, 18000]
}

df = pd.DataFrame(data)
